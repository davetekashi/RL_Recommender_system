# %%
import pandas as pd

data = pd.read_csv(r"C:\datasets\nutrients_csvfile.csv")
data
# Out:
#                       Food Measure  Grams Calories Protein Fat Sat.Fat Fiber  \
# 0               Cows' milk   1 qt.    976      660      32  40      36     0
# 1                Milk skim   1 qt.    984      360      36   t       t     0
# 2               Buttermilk   1 cup    246      127       9   5       4     0
# 3    Evaporated, undiluted   1 cup    252      345      16  20      18     0
# 4           Fortified milk  6 cups  1,419    1,373      89  42      23   1.4
# ..                     ...     ...    ...      ...     ...  ..     ...   ...
# 330    Fruit-flavored soda  12 oz.    346      161       0   0       0     0
# 331             Ginger ale  12 oz.    346      105       0   0       0     0
# 332              Root beer  12 oz.    346      140       0   0       0     0
# 333                 Coffee   1 cup    230        3       t   0       0     0
# 334                    Tea   1 cup    230        4       0   t       0     0
#
#     Carbs                   Category
# ...

# %%
class KnowledgeBase:
    def __init__(self, data_path):
        # Load the dataset
        self.data = pd.read_csv(data_path)
        
    def recommend_food_for_diabetes(self, max_carbs, max_sugar, max_calories):
        # Filter foods based on nutritional criteria suitable for diabetic patients
        filtered_foods = self.data[(self.data['Carbs'] <= max_carbs)&
                                   (self.data['Calories'] <= max_calories)]
        return filtered_foods[['food_name', 'carbs', 'calories']].reset_index(drop=True)

# Example usage
if __name__ == "__main__":
    # Initialize the knowledge base with the dataset
    knowledge_base = KnowledgeBase(r"C:\datasets\nutrients_csvfile.csv")

    # Set maximum nutritional values suitable for diabetic patients
    max_carbs = 20  # Maximum carbohydrates (in grams)
    max_sugar = 10  # Maximum sugar content (in grams)
    max_calories = 200  # Maximum calories per serving

    # Recommend foods for diabetic patients based on nutritional criteria
    recommended_foods = knowledge_base.recommend_food_for_diabetes(max_carbs, max_sugar, max_calories)
    print("Recommended foods for diabetic patients:")
    print(recommended_foods)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 23
#      20 max_calories = 200  # Maximum calories per serving
#      22 # Recommend foods for diabetic patients based on nutritional criteria
# ---> 23 recommended_foods = knowledge_base.recommend_food_for_diabetes(max_carbs, max_sugar, max_calories)
#      24 print("Recommended foods for diabetic patients:")
#      25 print(recommended_foods)
#
# Cell In[6], line 8, in KnowledgeBase.recommend_food_for_diabetes(self, max_carbs, max_sugar, max_calories)
#       6 def recommend_food_for_diabetes(self, max_carbs, max_sugar, max_calories):
#       7     # Filter foods based on nutritional criteria suitable for diabetic patients
# ----> 8     filtered_foods = self.data[(self.data['Carbs'] <= max_carbs)&
#       9                                (self.data['Calories'] <= max_calories)]
# ...
